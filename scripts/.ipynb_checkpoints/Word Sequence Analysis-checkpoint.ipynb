# %%
import numpy as np
import random
import seaborn as sns

# %%
word_sequence = np.random.randint(0, 10, size = (10000))
word_sequence
# Out:
# array([8, 8, 0, ..., 4, 4, 8])

# %%
sns.histplot(word_sequence)
# Out:
# <Axes: ylabel='Count'>

# %%
def build_dict(sequences):
    print(sequences)
# Out:
# [8 8 0 ... 4 4 8]

# %% [markdown]
# # Dictionary-based Compression Algorithms
# 1. LZW
# ![image.png](attachment:3a45ca72-bc03-4b5d-be95-b93f722e443b.png)
# 3. LZMW
# 4. LZAP
# 5. LZWL
# 6. LZ77
# 7. LZ78
# 8. LZSS
